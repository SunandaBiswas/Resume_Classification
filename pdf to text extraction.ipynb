# %% [markdown]
# Documentations :
# - https://pypi.org/project/pyresparser/
# -

# %% [markdown]
# # Process : 1

# %%
import PyPDF2 
pdfFileObj = open(r'C:\Users\sunan\Downloads\CV\SUNANDA__RESUME.pdf', 'rb') 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 

# extracting text from page 
str = " "
for i in range(1):
    str += pdfReader.getPage(i).extractText()
with open(r"C:\Users\sunan\Downloads\CV\Output.txt", "w", encoding = 'utf-8') as f:
    f.write(str)

# %%
# !pip install PyPDF2 
# importing required modules 
import PyPDF2

# %%
# creating a pdf file object 
pdfFileObj = open(r'C:\Users\sunan\Downloads\CV\SUNANDA__RESUME.pdf', 'rb')     
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
print(pdfReader.getDocumentInfo())  #showing document informations
# Out:
# {'/Author': 'Turbo', '/Creator': 'Microsoft® Word 2010', '/CreationDate': "D:20220320204454+06'00'", '/ModDate': "D:20220320204454+06'00'", '/Producer': 'Microsoft® Word 2010'}

# %%
# printing number of pages in pdf file 
print(pdfReader.numPages)
# Out:
# 1

# %%
# creating a page object 
pageObj = pdfReader.getPage(0) 
print(pageObj)
# Out:
# {'/Type': '/Page', '/Parent': IndirectObject(2, 0), '/Resources': {'/Font': {'/F1': IndirectObject(5, 0), '/F2': IndirectObject(8, 0), '/F3': IndirectObject(10, 0), '/F4': IndirectObject(14, 0), '/F5': IndirectObject(16, 0), '/F6': IndirectObject(21, 0), '/F7': IndirectObject(36, 0), '/F8': IndirectObject(41, 0), '/F9': IndirectObject(45, 0), '/F10': IndirectObject(58, 0)}, '/ExtGState': {'/GS7': IndirectObject(7, 0)}, '/XObject': {'/Image23': IndirectObject(23, 0), '/Image25': IndirectObject(25, 0), '/Image27': IndirectObject(27, 0), '/Image30': IndirectObject(30, 0), '/Image33': IndirectObject(33, 0), '/Image35': IndirectObject(35, 0)}, '/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI']}, '/Annots': [IndirectObject(12, 0), IndirectObject(13, 0), IndirectObject(29, 0), IndirectObject(32, 0), IndirectObject(43, 0), IndirectObject(44, 0), IndirectObject(50, 0), IndirectObject(51, 0), IndirectObject(52, 0), IndirectObject(53, 0), IndirectObject(54, 0), IndirectObject(55, 0), IndirectObject(56, 0), IndirectObject(57, 0)], '/MediaBox': [0, 0, 595.56, 842.04], '/Contents': IndirectObject(4, 0), '/Group': {'/Type': '/Group', '/S': '/Transparency', '/CS': '/DeviceRGB'}, '/Tabs': '/S', '/StructParents': 0}

# %%
# extracting text from page 
print(pageObj.extractText())
# Out:
#
#
# CONTACT
#
#
# Dhaka, Bangladesh
#
#
#
#
#
# +8801521215123
#
#
#
#
#
# biswas.sunanda9873@gmail.com
#
#
#
#
#
#
# Git
# H
# ub
#
#
#
#
# LinkedIn
#
#
# SKILLS
#
#
# P
# ROGRAMMING  LANGUAGES
#
#
#
# Python (
# Core
# ):
#
# Object Oriented
# Programming,
# Libraries
#
# -
#
# Scikit
# -
# Learn, Matplotlib, Seaborn, Numpy,
# Pandas, Plotly, Iplot, Geopy, Folium,
# Tensorflow,
#
# Keras,
#
# BeautifulSoup,
# Selenium
#
#
#
# Java (Familiarity)
#
#
#
# SQL:
# DDL &
#
# DML
# Operations,
# RDBMS
#
#
#
# HTML & CSS
#
# T
# OOLS
#
#
#
# Jupyter Notebook
# ,
#
# Google Colab
# ,
#
# Spyder
#
#
#
# Data reporting & Data
# VisualizationTools
# : Google Studio,
# Google Analytics, PowerBI
# ,
# Tableau,
# Excel
# , SPSS
#
#
#
# MySQL
# , SQLite
#
#
#
# Git
#
#
# S
# OFT  SKILLS
#
#
#
# Dedication, Consistency
# ,
#
# Leadership,
#
# Problem
#
# Solving
#
#
# REFERENCE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PROJECTS
#
# Bachelor of Science
#
# (January
#
# 2017
#
#
# September 2021)
#
#
#
# HSC
# (2014
#
#
# 2016)
#
#
#
#
# SSC
#
# (2013
#
#
# 2014)
#
#
#
# BRAC UNIVERSITY
#
# Computer Science & Engineering
#
# CGPA
# 3.21
#
# (Scale of
# 4.00
# )
#
#
# Savar Cantonment Public School &
# College
#
# GPA 5.00 (Scale of 5.00)
#
#
# Savar Cantonment Public School &
# College
#
# GPA 5.00 (Scale of 5.00)
#
# Machine Learning
#
# & Data Analysis
#
# Projects:
#
#
#
#
# Disease Prediction using Brain Images in multiclass
# image classification approach
#
#
#
# Fake News Classification System
#
#
#
#
# Geospatial Data Analysis using Zomato Restaurants dataset
#
#
#
# Predictive model on
# Next Day Rain
# fall
#
#
#
# Diabetes Prediction model based on medical records
#
#
#
# Predictive Analysis on Future Sales
#
#
#
# Sentiment Analyzer system with Twitter API data
#
#
#
# Stroke Prediction Model
#
#
#
# Bangladeshi Restaur
# a
# nt data analysis
#
# SUNANDA BISWAS
#
#
# A
# CADEMIC RESEARCH
#
# Estimation of air pollutants emissions in Bangladesh using Machine
# Learning
#
# Worked on developing Univariate time series forecasting model using MLP
# and LSTM architecture for estimation of different types of air pollutants
# emissions in Bangladesh that are i
# ndicators of the climate change of
# Bangladesh.
#
# Multi
# -
# modal Hate Speech Detection from Video Content
# (Ongoing)
#
# The research aim is to detect hateful contents through analyzing video
# frames, audio signals and extracted texts. Several algorithms such as LSTM,
#
# CNN based pretrained models and ensemble voting method has been used
# for the classification problem.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CERTIFICATION
#
# SQL: Data Reporting and Analysis
#
# LinkedIn Learning |
#
# 2021
#
# Exploratory Data An
# a
# lysis (EDA) for Machine Learning
#
# UDEMY |
#
# 2021
#
# Machine Learning from Basics to Advanced
#
# UDEMY |
#
# 2021
#
# Machine Learning using Python Programming
#
# UDEMY |
#
# 2021
#
#
#
#
# EXTRA
# -
# CURRICULAR ACTIVITIES
#
# -
#
# Certificate of Appreciation for Active Contribution as Assistant Director:
# BRAC University Computer
# Club (BUCC), Finance Department | 2021
#
# -
#
# Promoted as Assistant Director, BRAC University Computer Club
#
# (BUCC),
# Finance Department | 2019
# -
# 2020
#
# -
#
# Volunteering in the event BRACATHON 3.0 organized by BRAC | 2019
#
# -
#
# Certificate of Participation: Animated Film M
# aking | Residential Campus
# Activity, BRAC University | 2017
#
#
# Dr. Muhammad Iqbal Hossain
#
# Assistant Professor,
#
# Department of Computer Science and
# Engineering
#
# BRAC University, Dhaka, Bangladesh
#
# Contact: +88
# -
# 09617445122
#
# Email Id: iqbal.hossain@bracu.ac.bd
#
#
# EDUCATIONAL
# BACKGROUND
#
# WORK EXPERIENCE
#
# Data Analyst
#
# |
# October
# 2021
#
#
# January2022
#
# Pyceptron
#
#
#
# Information
#
# Technology Company, Bangladesh
#
# -
#
# Analyzing data to find business needs,
# making business
# decisions
# using python,
# SQL and PowerBI

# %% [markdown]
# # Process : 2

# %%
#!pip install --user https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz

# %%
#!pip install nltk 
#!pip install spacy==2.3.5 
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\users\sunan\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\sunan\anaconda3\lib\site-packages (from python-docx) (4.6.3)

# %%
import pandas as pd
import os
from pyresparser import ResumeParser
from docx import Document
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-d2906202e497> in <module>
#       1 import pandas as pd
#       2 import os
# ----> 3 from pyresparser import ResumeParser
#       4 from docx import Document
#
# ~\anaconda3\lib\site-packages\pyresparser\__init__.py in <module>
#       1 from . import utils
#       2 from . import constants
# ----> 3 from .resume_parser import ResumeParser
#       4
#       5 __all__ = [
#
# ~\anaconda3\lib\site-packages\pyresparser\resume_parser.py in <module>
#       4 import multiprocessing as mp
#       5 import io
# ----> 6 import spacy
#       7 import pprint
#       8 from spacy.matcher import Matcher
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\__init__.py in <module>
#       9
#      10 # These are imported as part of the API
# ---> 11 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      12 from thinc.api import Config
#      13
#
# ImportError: cannot import name 'prefer_gpu' from 'thinc.api' (C:\Users\sunan\anaconda3\lib\site-packages\thinc\api.py)

# %%
#filedd = input()

# %%
directory = r"C:\Users\sunan\Downloads"
file = r"SUNANDA__RESUME.pdf"

# %%
try:
    doc = Document()
    with open(file, 'r') as file:
        doc.add_paragraph(file.read())
    doc.save("text.docx")
    data = ResumeParser('text.docx').get_extracted_data()
    print(data['skills'])
except:
    data = ResumeParser('text.docx').get_extracted_data()
    print(data['skills'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-3f904f375f79> in <module>
#       3     with open(file, 'r') as file:
# ----> 4         doc.add_paragraph(file.read())
#       5     doc.save("text.docx")
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 808: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-3f904f375f79> in <module>
#       7     print(data['skills'])
#       8 except:
# ----> 9     data = ResumeParser('text.docx').get_extracted_data()
#      10     print(data['skills'])
#      11
#
# ~\anaconda3\lib\site-packages\pyresparser\resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      18         custom_regex=None
#      19     ):
# ---> 20         nlp = spacy.load('en_core_web_sm')
#      21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     418             return get_lang_class(name.replace("blank:", ""))()
#     419         if is_package(name):  # installed as package
# --> 420             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421         if Path(name).exists():  # path to model data directory
#     422             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\util.py in load_model_from_package(name, vocab, disable, exclude, config)
#     451     """
#     452     cls = importlib.import_module(name)
# --> 453     return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)  # type: ignore[attr-defined]
#     454
#     455
#
# ~\AppData\Roaming\Python\Python38\site-packages\en_core_web_sm\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\util.py in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     613     if not model_path.exists():
#     614         raise IOError(Errors.E052.format(path=data_path))
# --> 615     return load_model_from_path(
#     616         data_path,
#     617         vocab=vocab,
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     485     config_path = model_path / "config.cfg"
#     486     overrides = dict_to_dot(config)
# --> 487     config = load_config(config_path, overrides=overrides)
#     488     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     489     return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\util.py in load_config(path, overrides, interpolate)
#     644     else:
#     645         if not config_path or not config_path.is_file():
# --> 646             raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     647         return config.from_disk(
#     648             config_path, overrides=overrides, interpolate=interpolate
#
# OSError: [E053] Could not read config file from C:\Users\sunan\AppData\Roaming\Python\Python38\site-packages\en_core_web_sm\en_core_web_sm-2.3.1\config.cfg

# %%
data = ResumeParser(directory + file).get_extracted_data()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-937984208fdd> in <module>
# ----> 1 data = ResumeParser(directory + file).get_extracted_data()
#       2 data
#
# ~\anaconda3\lib\site-packages\pyresparser\resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      18         custom_regex=None
#      19     ):
# ---> 20         nlp = spacy.load('en_core_web_sm')
#      21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     418             return get_lang_class(name.replace("blank:", ""))()
#     419         if is_package(name):  # installed as package
# --> 420             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421         if Path(name).exists():  # path to model data directory
#     422             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model_from_package(name, vocab, disable, exclude, config)
#     451     """
#     452     cls = importlib.import_module(name)
# --> 453     return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)  # type: ignore[attr-defined]
#     454
#     455
#
# ~\AppData\Roaming\Python\Python38\site-packages\en_core_web_sm\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     613     if not model_path.exists():
#     614         raise IOError(Errors.E052.format(path=data_path))
# --> 615     return load_model_from_path(
#     616         data_path,
#     617         vocab=vocab,
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     485     config_path = model_path / "config.cfg"
#     486     overrides = dict_to_dot(config)
# --> 487     config = load_config(config_path, overrides=overrides)
#     488     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     489     return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_config(path, overrides, interpolate)
#     644     else:
#     645         if not config_path or not config_path.is_file():
# --> 646             raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     647         return config.from_disk(
#     648             config_path, overrides=overrides, interpolate=interpolate
#
# OSError: [E053] Could not read config file from C:\Users\sunan\AppData\Roaming\Python\Python38\site-packages\en_core_web_sm\en_core_web_sm-2.3.1\config.cfg
